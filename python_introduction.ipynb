# %%
v = 5 # variable cannot starts with number
v
# Out:
# 5

# %%
import keyword  # reserve words 
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # value == datatype
# - int
# - float
# - bool
# - complex
# - str

# %%
i = 40
i
# Out:
# 40

# %%
type(i)
# Out:
# int

# %%
fuel = 101.34
type(fuel)
# Out:
# float

# %%
a =  True
type(a)     # type() is an inbuilt function, only one argument (a) is pass,  **a**= argument , variable (a) is pass in the argument
# Out:
# bool

# %%
c = 10+2j
type(c)    # in complex 10 = **real part** and 2 = **imginary part**
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 2.0

# %%
'''nareshit 
technology'''   # triple quote
# Out:
# 'nareshit \ntechnology'

# %%
'nareshit
technology'  # single qoute will not work on next line
# Out:
#   Cell In[12], line 1
#     'nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # function ends with bracket ()
# # function()
#
# - asian_car() - 0 argument or 0 parameter
# -  us_car(duston, ford) - 2 argument or 2 parameter
# - german_car(audi, bmw, volk) - 3 argument or 3 parameter
#
# ### we have seen both , function with argument and function without argument
# ### both argument and parmeter are same

# %% [markdown]
# ### function are 2 parts
# - inbuilt function  - type(), len(),print(), max(), min()
# - user define function
#
# ### chatgpt() - model trained on 450 million parameter( that is why it required heavy GPU and called as LLM - large language model)

# %%
# 27 may --- python(day 2)
## User input function in python || command line input

x = input()
x                      # in langraph function /project these input functions are very important
# Out:
# '3'

# %%
x = input()
y = input()
z = x+y                  # by default input function read string, so we have to change it to int 
print(z)                 # input() ==== in python read as string
# Out:
# 23

# %%
x = int(input('enter first number : '))
y = int(input('enter second number : '))
z = x+y              
print(z)
# Out:
# 10

# %% [markdown]
# ### in prompt engineering using the help of input() function we can create a prompt
# ### it will help build prompt of your project

# %% [markdown]
# ## print() === print function
# #### it is a inbuilt function like ==== type(), print(), len(), min(), max()
# #### we use print function to display each and every output

# %% [markdown]
# ## 28 May ---- exceptional handling

# %%
a = 5 
b = 2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c = 9
d = 0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
c = 9
d = 0
print('bye')   # 1st it will print 
print(c/d)     # error so the excution stops
# Out:
# bye
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 c = 9
#       2 d = 0
#       3 print('bye')
# ----> 4 print(c/d)
#
# ZeroDivisionError: division by zero

# %%
c = 9
d = 0

print(c/d)      # excution stop so 2nd line of code will not execute
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 c = 9
#       2 d = 0
#       3
# ----> 4 print(c/d)      # excution stop so 2nd line of code will not get print
#       5 print('bye')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Try and except === exceptional handling

# %%
c = 9
d = 0

try:
    print(c/d)   
except Exception as e:  
    print('An error has occured : ', e)
print('bye')
# Out:
# An error has occured :  division by zero
# bye

# %% [markdown]
# #### whenever try block error then only except block will works
# #### if try block NO error , then it will SKIP the except block      # session26- 30 dec

# %%
c = 9
d = 0

try:
    print(c/d)   
except Exception as e:  
   print('bye')
# Out:
# bye

# %%
c = 9
d = 0

try:
    print(c/d)   
except Exception as e:  
    print('An error has occured: ', e)   # we write ** e** to read the error message
    print(e)
# Out:
# An error has occured:  division by zero
# division by zero

# %%
c = 9
d = 0

try:
    print(c/d)   
except Exception:  
    print('bye')   # exception work without **e**
# Out:
# bye

# %% [markdown]
# ## print() ----- print function

# %%
num1 = 20
num2 = 30 
add= (num1+num2)
print(add)
# Out:
# 50

# %%
num1 = 40
num2 = 50 
add= (num1+num2)
print('the addition of ', num1, 'and' ,num2, 'is =' , add)
# Out:
# the addition of  40 and 50 is = 90

# %% [markdown]
# ## print with format method

# %%
num1 = 40
num2 = 50 
add= (num1+num2)
print('the addition of {} and {} is = {}'.format(num1,num2,add))
# Out:
# the addition of 40 and 50 is = 90

# %% [markdown]
# ## print with f string

# %%
num1 = 79
num2 = 23
add= (num1+num2)
print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 79 and 23 is = 102

# %%
print('hello')
print('Good Morning')
# Out:
# hello
# Good Morning

# %%
print('hello', end = " ")
print('Good Morning')
# Out:
# hello Good Morning

# %% [markdown]
# # 29 May - python functions

# %% [markdown]
# # user define function
#
# ####    def genai():                        ======== define a function
# ####        print('hello team')             ======== print the statment
#
# ####    genai                               ======== call the function

# %%
def greet():                                   # without argument or parameter
    print('Good morning from India')           # indentation

greet()

# %%
def greet():                                   
    print('Good morning from India')           

greet()   

def greet():                                   
    print('Good morning from USA')           

greet()
# Out:
# Good morning from India
# Good morning from USA

# %%
def greet():                                   
    print('Good morning from India')           
                     
    print('Good morning from USA')          # instead of write 2 function we can print 2 time and then call the function

greet()
greet()
# Out:
# Good morning from India
# Good morning from USA
# Good morning from India
# Good morning from USA

# %%
def add(a,b):   # function with 2 arguments
    print(a+b)

add(40,12)
# Out:
# 52

# %%
def add(a,b):   # a , b =====  formal argument  
    c = a+b
    print(c)

add(14,16)      # 14, 16 ==== actual argument
# Out:
# 30

# %% [markdown]
# ### In ML == there is model parameter tuning and hyper parameter tunning
# ### In LLM model fine tune is there

# %%
def add(a,b):   # a , b =====  I define 2 formal argument  
    c = a+b
    print(c)

add(14,16, 12)  # but here i have given 3 actual argumnet == incorrect a = 14, b= 16 but 12 there is formal argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       1 def add(a,b):   # a , b =====  formal argument
#       2     c = a+b
#       3     print(c)
#       4
# ----> 5 add(14,16, 12)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(a,b):   # a , b =====  formal argument  
    c = a+b
    print(c)

r = add(3,2)
print(r)
print(type(r))
# Out:
# 5
# None
# <class 'NoneType'>

# %% [markdown]
# #### while working on a function ,  if we create any variable , we must call the variable with RETURN keyword
# #### DO NOT write print()

# %%
def add(a,b):   # a , b =====  formal argument  
    c = a+b
    return c

r = add(3,2)
print(r)
print(type(r))
# Out:
# 5
# <class 'int'>

# %% [markdown]
# ## Function Arguments
# ###  1  formal argument == when we define
# ###  2  actual argument == when we call the function
#
# #### actual argument is divided into
# #####  positional argument
# #####  keyword argument
# #####  default argument

# %% [markdown]
# ###  There are many more but will be used then not more in genai
# ##### variable length (*)
# ##### kwargs (keyword + variable length ())

# %%
def company(name, age):
    print('nit')
    print(25)

company('nit', 25)
# Out:
# nit
# 25

# %%
def company(name, age):    
    print('nit')
    print(25)

company('nit')      # positional argument as age is missing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       1 def company(name, age):
#       2     print('nit')
#       3     print(25)
#       4
# ----> 5 company('nit')
#
# TypeError: company() missing 1 required positional argument: 'age'

# %%
def company(name, age):    
    print('nit')
    print(25)

company(23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       1 def company(name, age):
#       2     print('nit')
#       3     print(25)
#       4
# ----> 5 company(23)
#
# TypeError: company() missing 1 required positional argument: 'age'

# %%
def company(name, age):    
    print('nit')
    print(25)

company('nit',23, 21)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       1 def company(name, age):
#       2     print('nit')
#       3     print(25)
#       4
# ----> 5 company('nit',23, 21)
#
# TypeError: company() takes 2 positional arguments but 3 were given
